# %% [markdown]
# <div style='background-color: #ffcccc; padding: 15px; border-radius: 5px; margin-bottom: 20px; color: black; border-left: 5px solid red;'>
#     <h1 style='text-align: center; margin: 0; color: red;'>THUẬT TOÁN K - NEAREST NEIGHBORS (KNN)</h1>
# </div>

# %% [markdown]
# <div style="background-color: #fffbe6; padding: 20px; border-radius: 8px; margin-bottom: 24px; color: #333; border-left: 5px solid #faad14; font-family: Arial, sans-serif; line-height: 1.6;">
#
#   <h2 style="margin-top: 0; color: #faad14;">📌 Tóm tắt và mô tả thuật toán K - Nearest Neighbors (KNN)</h2>
#
#   <h3 style="text-align: center; font-weight: bold; color: #fa8c16; margin-bottom: 10px;">PIPELINE CHUNG CHO BÀI TOÁN</h3>
#
#   <h4 style="color: #d48806;">🔹 Tổng quan về Machine Learning</h4>
#   <ul>
#     <li><strong>Supervised Learning:</strong> Dữ liệu có nhãn đầu ra.</li>
#     <li><strong>Unsupervised Learning:</strong> Dữ liệu không nhãn, dùng để phân cụm hoặc rút trích đặc trưng.</li>
#     <li><strong>Semi - Supervised Learning:</strong> Kết hợp dữ liệu có và không nhãn.</li>
#     <li><strong>Reinforcement Learning:</strong> Học thông qua tương tác với môi trường, nhận phản hồi (reward).</li>
#   </ul>
#
#   <h4 style="color: #d48806;">🔹 Giới thiệu KNN</h4>
#   <p>
#     <strong>K - Nearest Neighbors (KNN)</strong> là một trong những thuật toán <strong>học có giám sát (Supervised Learning)</strong> đơn giản và phổ biến nhất trong Machine Learning.
#     Mô hình này không thực sự "học" từ dữ liệu huấn luyện mà chỉ bắt đầu tính toán khi có dữ liệu mới cần dự đoán (gọi là <strong>lazy learning</strong>).
#     KNN áp dụng được cho cả hai loại của bài toán Supervised Learning là:
#   </p>
#   <ul>
#     <li><strong>Phân loại (Classification)</strong></li>
#     <li><strong>Hồi quy (Regression)</strong></li>
#   </ul>
# <img src="Screenshot 2025-06-11 213001.png" width="300" style="display: block; margin: auto;">
#
#
#   <h4 style="color: #d48806;">🔹 Các bước thực hiện thuật toán KNN (Classification)</h4>
#   <ol>
#     <li>Chọn số lượng <strong>K láng giềng gần nhất</strong>.</li>
#     <li>Tính <strong>khoảng cách</strong> đến các điểm trong tập huấn luyện (thường dùng: Euclidean, Manhattan, Minkowski).</li>
#     <img src="Screenshot 2025-06-11 214630.png" width="570" style="display: block; margin: auto;">
#     <li>Chọn <strong>K điểm gần nhất</strong>.</li>
#     <li>Thực hiện <strong>voting</strong>: nhãn xuất hiện nhiều nhất sẽ là kết quả dự đoán.</li>
#   </ol>
#
#   <h4 style="color: #d48806;">🔹 Cách chọn giá trị K phù hợp</h4>
#   <ul>
#     <li><strong>K nhỏ:</strong> Dễ bị overfitting.</li>
#     <li><strong>K lớn:</strong> Tổng quát tốt hơn, nhưng có thể underfitting.</li>
#     <li><strong>K lẻ:</strong> Tránh được tình huống hòa phiếu.</li>
#     <li><strong>K chẵn:</strong> Dễ xảy ra hòa phiếu, nên dùng trọng số:
#       <ul>
#         <li><code>uniform</code>: mọi điểm có trọng số bằng nhau.</li>
#         <li><code>distance</code>: điểm gần hơn có trọng số cao hơn.</li>
#       </ul>
#     </li>
#   </ul>
#
#   <h4 style="color: #d48806;">🔹 KNN trong bài toán Hồi quy (Regression)</h4>
#   <p>
#     Sau khi chọn K hàng xóm, ta tính <strong>trung bình (hoặc trung vị)</strong> của các giá trị mục tiêu để đưa ra dự đoán thay vì voting như phân loại.
#   </p>
#
#   <h4 style="color: #d48806;">🔹 Các phương pháp tìm hàng xóm</h4>
#   <ul>
#     <li><strong>Brute Force:</strong> So sánh với tất cả các điểm. Đơn giản nhưng chậm.</li>
#     <li><strong>K - D Tree:</strong> Cây nhị phân phân vùng không gian, tối ưu tìm kiếm theo trục tọa độ (ưu tiêu được sử dụng).</li>
#     <li><strong>Ball Tree:</strong> Phân vùng không gian theo hình cầu, hiệu quả với dữ liệu có nhiều chiều.</li>
#   </ul>
#
#   <h4 style="color: #d48806;">🔹 Đánh giá hiệu suất mô hình</h4>
#   <ul>
#     <li><strong>Accuracy</strong> không đủ để đánh giá hiệu quả.</li>
#     <li>Dùng thêm:
#       <ul>
#         <li><strong>Confusion Matrix</strong></li>
#         <li><strong>Precision:</strong> Dự đoán dương → đúng bao nhiêu?</li>
#         <li><strong>Recall:</strong> Có bệnh thật → phát hiện bao nhiêu?</li>
#       </ul>
#     </li>
#   </ul>
#
#   <h4 style="color: #d48806;">🔹 Ưu và nhược điểm</h4>
#   <p><strong>Ưu điểm:</strong></p>
#   <ul>
#     <li>Độ phức tạp tính toán của quá trình huấn luyện bằng 0</li>
#     <li>Dễ hiểu, dễ triển khai</li>
#     <li>Việc dữ đoán dữ liệu mới rất đơn giản (sau khi đã xác định được các điểm lân cận (láng giềng gần nhất)</li>
#     <li>Không cần giả sử về phân phối của các class</li>
#   </ul>
#   <p><strong>Nhược điểm:</strong></p>
#   <ul>
#     <li>Tốn thời gian với dữ liệu lớn</li>
#     <li>Nhạy cảm với outlier và rất nhảy cảm với nhiễu khi K nhỏ</li>
#     <li>Hiệu quả giảm nếu số chiều quá cao (curse of dimensionality)</li>
#   </ul>
#
#   <h4 style="color: #d48806;">🔹 Ứng dụng thực tế</h4>
#   <ul>
#     <li>Nhận diện hình ảnh/khuôn mặt</li>
#     <li>Dự đoán giá nhà, bất động sản</li>
#     <li>Phân nhóm khách hàng</li>
#     <li>Phân loại email, văn bản</li>
#   </ul>
#
#   <hr style="border-top: 1px dashed #faad14;">
#   <p style="font-size: 14px; color: #8c8c8c;">
#     🔎 <strong>Tham khảo:</strong> Tài liệu của Hoàng-Nguyên Vũ, Ngọc Trúc – AI Vietnam Course 2024
#   </p>
# </div>

# %% [markdown]
# <div style='background-color:  #fffbe6; padding: 15px; border-radius: 5px; margin-bottom: 20px; color: black; border-left: 5px solid red;'>
#     <h1 style='text-align: center; margin: 0; color: red;'>Build thuật toán KNN - Classification bằng hàm tự định nghĩa</h1>
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import *



## Bước 1: Đọc file dữ liệu

def get_input(file_can_doc):
    X_data = np.genfromtxt(file_can_doc, delimiter = ',', skip_header = 1, dtype= str);
    ## Nếu mà ta không khai báo trong thư viện genfromtxt thì các dữ liệu được đọc vào dưới dạng số
    ## Mà label thì ở dạng str nên ta cần ép khai dtype = str trong hàm genfromtxt để hàm đọc được chuỗi
    ## Hơn nữa, nếu làm thì sẽ ảnh hưởng đến các dữ liệu số trong các cột khác, vì ở bước tính distance giữa các điểm mẫu (hàng xóm) với item
    ## Thì ta cần ép kiểu sang float để tính toán.

    trainingSet = X_data[:149, 1:]
    testingSet = X_data[149:, 1:-1]  ## Lưu ý: Bỏ đi lable - vì label này cần được dự đoán

    return trainingSet, testingSet

## Bước 2: Viết hàm tính khoảng cách giữa hai điểm
def computeDistance(dataPoint1, dataPoint2):
    result = 0;
    for i in range(4):
        result += (float(dataPoint1[i]) - float(dataPoint2[i])) ** 2
    result = sqrt(result)
    return result

## Bước 3: Viết hàm chọn ra K hàng xóm láng giếng gần nhất của iteam cần dự đoán nhãn

def computeKnearestNeighbor(trainingSet, item, k):
    distances = []
    for dataPoint in trainingSet:
        distances.append(
            { "label": dataPoint[-1],
               "value": computeDistance(dataPoint, item)
            }
        )

    distances.sort(key = lambda x: x["value"])
    labels = [item["label"] for item in distances]

    return labels[:k]

## Bước 4: Viết hàm vote để dự đoán nhãn của item thông qua của K hàng xóm gần nhất

def voteTheDistances(array):
    labels = set(array)
    result = ""
    maxOccur = 0
    for label in labels:
        num = array.count(label)
        if (num > maxOccur):
            maxOccur = num
            result = label

    return result


###-------------------------CHƯƠNG TRÌNH CHÍNH-----------------------------###
if __name__ == "__main__":
    k = 5;
    trainingSet, testingSet = get_input("Iris(1).csv")
    for item in testingSet:
        labels = computeKnearestNeighbor(trainingSet, item, k)
        label_prediction =  voteTheDistances(labels)
        print(f"Nhãn dữ liệu cần dự đoán cho {item} là: {label_prediction}")
# Out:
# Nhãn dữ liệu cần dự đoán cho ['5.9' '3.0' '5.1' '1.8'] là: Iris-virginica

# %% [markdown]
# <div style='background-color:  #fffbe6; padding: 15px; border-radius: 5px; margin-bottom: 20px; color: black; border-left: 5px solid red;'>
#     <h1 style='text-align: center; margin: 0; color: red;'>How to select K in K - NN</h1>
# </div>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

## Bước 1: Chọn hàm đọc và xử lý dữ liệu đầu vào bằng pandas
def normalized_data(X_data):
    n = len(X_data);
    m = len(X_data[0])
    

    # Tính trung bình mỗi cột
    mean_data = [0] * m
    for j in range(m):
        for i in range(n):
            mean_data[j] += X_data[i][j]
        mean_data[j] /= n

    # Tính độ lệnh chuẩn theo mỗi cột
    std_data = [0] * m
    for j in range(m):
        for i in range(n):
            std_data[j] += (X_data[i][j] - mean_data[j]) ** 2
        std_data[j] = (std_data[j] / (n - 1)) ** 0.5  ## sqrt(S / (n - 1__
    
    ## Chuẩn hóa Z-score cho từng phần tử

    X_normalized = []
    for i in range(n):
        row = []
        for j in range(m):
            if (std[j] != 0):
                row.append((X_data[i][j] - mean_data[j]) / std_data[j])
            else:
                row.append(0) # Tránh chia cho 0

        X_normalized.append(row)


    return X_normalized
    
def get_input_by_pandas(file_can_doc):
    ## Đọc file csv và đặt lại tiêu đề
    names = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Class']
    df = pd.read_csv(file_can_doc, names = names, header = 0)
    X_data = df.iloc[:, :-1].values
    y_data = df.iloc[:, -1].values

    ## Phân thành các tập train, test đối với features và label
    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size = 0.2, random_state = 42)
    
    '''
    X_train, X_test có kiểu dữ liệu là NumPy array 2D
    y_train, y_test có kiểu dữ liệu là NumPy array 1D
    '''

    ## Tiến hành chuẩn hóa dữ liệu bằng hàm tự định nghĩa phía trên
    # X_train_normalize = normalized_data(X_train)
    # X_test_normalize = normalized_data(X_test)

    ## Tiến hành chuẩn hóa dữ liệu bằng thư viện của sklearn
    scaler = StandardScaler()
    scaler.fit(X_train)

    X_train_normalize = scaler.transform(X_train)
    X_test_normalize = scaler.transform(X_test)


    return X_train_normalize, X_test_normalize, y_train, y_test

from sklearn.neighbors import KNeighborsClassifier

def KNN(n_neighbors, X_train, y_train):
    classifier = KNeighborsClassifier(n_neighbors = n_neighbors, weights = 'uniform')
    classifier.fit(X_train, y_train)

    return classifier


    

if __name__ == "__main__":
    n_neighbors = 5;
    X_train_normalize, X_test_normalize, y_train, y_test = get_input_by_pandas("iris(1).csv")
    classifier = KNN(n_neighbors, X_train_normalize, y_train)

    y_pred = classifier.predict(X_test_normalize)
    print(y_pred != y_test)


    from sklearn.metrics import accuracy_score, classification_report
    print(round(accuracy_score(y_test, y_pred), 2))
    print(classification_report(y_test, y_pred))
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False]
# 1.0
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00         9
#  Iris-virginica       1.00      1.00      1.00        11
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30

# %%
error = []
# Calculating accuracy for K-values between 1 and 30
for i in range(1, 50):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train_normalize, y_train)
    pred_i = knn.predict(X_test_normalize)
    error.append(accuracy_score(pred_i,y_test))

plt.figure(figsize=(12, 5))
plt.plot(range(1, 50), error, color='blue', marker='o',
        markerfacecolor='yellow', markersize=10)
plt.title('Accuracy vs K Value')
plt.xlabel('K Value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# <div style='background-color:  #fffbe6; padding: 15px; border-radius: 5px; margin-bottom: 20px; color: black; border-left: 5px solid red;'>
#     <h1 style='text-align: center; margin: 0; color: red;'>Optimal K in KNN </h1>
#      <h2 style='text-align: center; margin: 0; color: red;'>Tối ưu hóa K cho mô hình KNN - đánh giá trọng số cho các điểm lân cận</hh2>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import neighbors, datasets
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report

# %%
#---Demo---#
iris = np.genfromtxt("Iris(1).csv", delimiter = ',', skip_header = 1, dtype = str)
iris_X = iris[:, :-1]
iris_X = iris_X.astype(float)
iris_y = iris[:, -1]
'''
np.unique(iris) --> Trả về số lớp phân loại (số nhãn khác nhau) của iris
len(iris) --> Trả về số lượng chiều dài của mẫu dữ liệu (số dòng dữ liệu)
'''
print('Number of classes: %d' %len(np.unique(iris_y)))
print('Number of data points: %d' %len(iris_y))
# Out:
# Number of classes: 3
# Number of data points: 150

# %%
from sklearn.model_selection import train_test_split
'''
À! Câu hỏi của bạn là: Có cần phải gán đúng thứ tự X_train, X_test, y_train, y_test khi dùng train_test_split không?

👉 Câu trả lời: Có, bạn phải gán đúng thứ tự.
'''
'''
test_size = a tức là dữ liệu trên tập test có a dòng và số cột bằng số cột của tập train gốc
'''
X_train, X_test, y_train, y_test = train_test_split(
    iris_X, iris_y, test_size = 50, random_state = 42)

print("Training size: %d" %len(y_train))
print("Test size    : %d" %len(y_test))
# Out:
# Training size: 100
# Test size    : 50

# %%
clf = neighbors.KNeighborsClassifier(n_neighbors = 8, p = 2) 
## Nếu không khai báo weights = gì trong hàm neigbors.KNeighborsClassifier thì
## thư viện tự hiểu là chúng ta đang để giá trị mặc định weights = uniform
## Xem các trọng số của K hàng xóm láng giềng gần item nhất là như nhau, và chọn ngẫu nhiên nếu K là số chẵn)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print("Kết quả dự đoán cho 20 test data points:")
print("Predicted labels: ", y_pred[20:40])
print("Ground truth    : ", y_test[20:40])

print ("Accuracy of 10NN with major voting: %.2f %%" %(100*accuracy_score(y_test, y_pred)))
print(classification_report(y_test, y_pred))
# Out:
# Kết quả dự đoán cho 20 test data points:
# Predicted labels:  ['Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa']
# Ground truth    :  ['Iris-setosa' 'Iris-virginica' 'Iris-setosa' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa']
# Accuracy of 10NN with major voting: 98.00 %
#                  precision    recall  f1-score   support
#
#     Iris-setosa       0.95      1.00      0.97        19
# Iris-versicolor       1.00      0.93      0.97        15
# ...

# %%
## Sử dụng thư viện để đánh trọng số cho trường hợp k chẵn (tức n_neighbors chẵn)
clf = neighbors.KNeighborsClassifier(n_neighbors = 8, p = 2, weights = 'distance')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print ("Accuracy of 10NN with major voting: %.2f %%" %(100*accuracy_score(y_test, y_pred)))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy of 10NN with major voting: 100.00 %
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        15
#  Iris-virginica       1.00      1.00      1.00        16
#
#        accuracy                           1.00        50
#       macro avg       1.00      1.00      1.00        50
#    weighted avg       1.00      1.00      1.00        50

# %% [markdown]
# # Hiểu về `weights='distance'` trong KNeighborsClassifier (scikit-learn)
#
# Khi bạn dùng `weights='distance'` trong `KNeighborsClassifier`, ý nghĩa là **mỗi láng giềng (neighbor) được gán trọng số tỉ lệ nghịch với khoảng cách đến điểm cần dự đoán**.
#
# ---
#
# ## ✅ Cụ thể:
#
# Trong KNN, để dự đoán nhãn cho một điểm mới $ x $, ta tìm **k điểm gần nhất** trong tập huấn luyện.
#
# - Mặc định (`weights='uniform'`): mỗi điểm góp **1 phiếu bằng nhau**.
# - Với `weights='distance'`: điểm gần hơn sẽ có **ảnh hưởng lớn hơn**.
#
# ---
#
# ## 📐 Công thức:
#
# Giả sử:
# - $ x $: điểm cần dự đoán
# - $ x_i $: điểm láng giềng gần nhất thứ $ i $
# - $ d_i = \| x - x_i \| $: khoảng cách từ $ x $ đến $ x_i $
# - $ y_i $: nhãn của $ x_i $
#
# **Trọng số được tính:**
#
# $$
# w_i = \frac{1}{d_i}
# $$
#
# Tổng trọng số cho từng nhãn được tính, sau đó **lấy nhãn có tổng trọng số cao nhất** làm kết quả dự đoán.
#
# ---
#
# ## 🧠 Ví dụ trực quan:
#
# Giả sử có 3 láng giềng gần nhất như sau:
#
# | Láng giềng | Nhãn | Khoảng cách | Trọng số |
# |------------|------|-------------|----------|
# | A          | 0    | 0.1         | 10.0     |
# | B          | 1    | 0.5         | 2.0      |
# | C          | 1    | 0.2         | 5.0      |
#
# - Tổng trọng số cho nhãn 0: **10.0**
# - Tổng trọng số cho nhãn 1: **2.0 + 5.0 = 7.0**
#
# ➡️ Kết quả dự đoán là **nhãn 0**, vì nó có tổng trọng số cao hơn.
#
# ---
#
# ## ✅ Khi nào nên dùng `weights='distance'`?
#
# - Khi bạn muốn **ưu tiên láng giềng gần hơn**.
# - Giúp giảm ảnh hưởng của **outlier ở xa**.
# - Dùng tốt với **dữ liệu có nhiễu nhẹ**.

# %%
## KNN với trọng số tự định nghĩa
def myweight(distances):
    sigma_2 = 0.5
    weights_i = np.exp(-distances ** 2/ sigma_2)
    return weights_i
    
clf = neighbors.KNeighborsClassifier(n_neighbors = 8, p = 2, weights = myweight)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

print("Accuracy of 10NN with major voting: %.2f %%" %(100 * accuracy_score(y_test, y_pred)))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy of 10NN with major voting: 100.00 %
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        15
#  Iris-virginica       1.00      1.00      1.00        16
#
#        accuracy                           1.00        50
#       macro avg       1.00      1.00      1.00        50
#    weighted avg       1.00      1.00      1.00        50

# %%
### Khảo sát trên tập dữ liệu TeleCustomers.csv

## Bước 1: Hoàn thành việc đọc dữ liệu từ file csv
TeleCustomers = np.genfromtxt('TeleCustomers.csv', delimiter = ',', skip_header = 1)

## Bước 2: Chia dữ liệu thành các tập traning và tập testing
### --> Chia tập dữ liệu thủ công bằng tay 
'''
X_train = TeleCustomers[:801, :-1]
X_test = TeleCustomers[801:, :-1]
y_train = TeleCustomers[:801, -1]
y_test =  TeleCustomers[801:, -1]
'''
### --> Tập dùng thư viện sklearn
from sklearn.model_selection import train_test_split
X_data = TeleCustomers[:, :-1]
y_data = TeleCustomers[:, -1]

X_train, X_test, y_train, y_test = train_test_split(
    X_data, y_data, test_size = 200, random_state = 42)

### --> Chuẩn hóa dữ liệu
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaler = scaler.fit_transform(X_train)
X_test_scaler = scaler.transform(X_test)


from sklearn import neighbors
from sklearn import metrics
### --> Train Model and Predict
k = 4
clf = neighbors.KNeighborsClassifier(n_neighbors = k, p = 2, weights = 'distance')
clf.fit(X_train_scaler, y_train)
y_pred = clf.predict(X_test_scaler)

print("Accuracy of model at K = 4 is", metrics.accuracy_score(y_test, y_pred))
print(y_pred != y_test)
# Out:
# Accuracy of model at K = 4 is 0.32
# [ True  True  True  True  True  True False  True False  True  True False
#   True False  True  True False  True  True  True False  True  True  True
#   True  True  True  True  True  True  True  True False  True False  True
#  False  True  True  True  True False  True False False False  True  True
#   True  True  True  True  True  True False  True False False  True False
#   True  True  True  True  True False  True False  True False  True  True
#  False  True False  True False False  True  True  True  True False  True
#   True  True False False  True  True  True  True  True  True False  True
#  False  True False False  True False False False  True False False False
#   True  True  True  True False  True  True  True  True  True False False
#  False  True  True  True False  True  True  True  True False False False
#  False False  True  True  True  True  True  True  True False False False
# ...

# %%
error_rate = []
for i in range(1,40):
 knn = neighbors.KNeighborsClassifier(n_neighbors=i,weights = 'distance')
 knn.fit(X_train_scaler, y_train)
 pred_i = knn.predict(X_test_scaler)
 error_rate.append(np.mean( pred_i != y_test))

plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed',
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
print("Minimum error:-",min(error_rate),"at K =",error_rate.index(min(error_rate)))
# Out:
# Minimum error:- 0.63 at K = 16

# %%
acc = []
# Will take some time
from sklearn import metrics
for i in range(1,40):
    neigh = neighbors.KNeighborsClassifier(n_neighbors = i,weights = 'distance').fit(X_train,y_train)
    yhat = neigh.predict(X_test)
    acc.append(metrics.accuracy_score(y_test, yhat))

plt.figure(figsize=(10,6))
plt.plot(range(1,40),acc,color = 'blue',linestyle='dashed',
         marker='o',markerfacecolor='red', markersize=10)
plt.title('accuracy vs. K Value')
plt.xlabel('K')
plt.ylabel('Accuracy')
print("Maximum accuracy:-",max(acc),"at K =",acc.index(max(acc)))
# Out:
# Maximum accuracy:- 0.38 at K = 17

# %% [markdown]
# <div style='background-color:  #fffbe6; padding: 15px; border-radius: 5px; margin-bottom: 20px; color: black; border-left: 5px solid red;'>
#     <h1 style='text-align: center; margin: 0; color: red;'>So sánh tính ổn định của hai mô hình Linear Regression và KNN cho bài toán hồi quy</h1>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv("cruise_ship_info.csv")
df.head()

# chọn đặc trưng
cols_selected = ['Tonnage', 'passengers', 'length', 'cabins','crew']
X = df[cols_selected].iloc[:,0:4].values
y = df[cols_selected]['crew']

# Chuẩn hóa cho y
sc_y = StandardScaler()

## Pipeline
pipe_lr = Pipeline([('scl', StandardScaler()),
                    ('slr', LinearRegression())])
pipe_knn = Pipeline([('scl', StandardScaler()),
                   ('knn', KNeighborsRegressor())])

## Tạo một list để lưu điểm
train_score_lr = []
train_score_knn =  []

## Số lần lặp
n = 15

# Đánh giá mô hình
for i in range(n):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3,  random_state = i)
    
    y_train_std = sc_y.fit_transform(y_train.to_numpy().reshape(-1, 1)).flatten()

    
    train_score_lr = np.append(train_score_lr, np.mean(cross_val_score(pipe_lr, 
                                                                       X_train, y_train_std, 
                                                                        scoring = 'r2', cv = 10)))
    train_score_knn = np.append(train_score_knn, np.mean(cross_val_score(pipe_knn, 
                                                                         X_train, y_train_std,
                                                                        scoring = 'r2', cv = 10)))

# Chuyển thành array
train_score_lr = np.array(train_score_lr)
train_score_knn = np.array(train_score_knn)

# Tính trung bình và độ lệch chuẩn
train_mean_lr = np.mean(train_score_lr)
train_std_lr = np.std(train_score_lr)
train_mean_knn = np.mean(train_score_knn)
train_std_knn = np.std(train_score_knn)
print('R2 train for lr: %.3f +/- %.3f' %
                             (train_mean_lr,train_std_lr))
print('R2 train for knn_lr: %.3f +/- %.3f' %
                             (train_mean_knn,train_std_knn))
# Out:
# R2 train for lr: 0.914 +/- 0.013
# R2 train for knn_lr: 0.865 +/- 0.024

# %%
## Plot đồ thị hai mô hình để trực quan hóa
import matplotlib.pyplot as plt

plt.figure(figsize=(15,11))
plt.plot(range(n),train_score_lr,color='blue', linestyle='dashed',
         marker='o',markerfacecolor='blue', markersize=10,
         label='linear regression')
plt.fill_between(range(n),
                 train_score_lr + train_std_lr,
                 train_score_lr - train_std_lr,
                 alpha=0.15, color='blue')
plt.plot(range(n),train_score_knn,color='green', linestyle='dashed',
         marker='s',markerfacecolor='green', markersize=10,
         label = 'Kneighbors regression')
plt.fill_between(range(n),
                 train_score_knn + train_std_knn,
                 train_score_knn - train_std_knn,
                 alpha=0.15, color='green')
plt.grid()
plt.ylim(0.7,1)
plt.title('Mean cross-validation R2 score vs. random state parameter', size = 14)
plt.xlabel('Random state parameter', size = 14)
plt.ylabel('Mean cross-validation R2 score', size = 14)
plt.legend()
plt.show()

# %% [markdown]
# <div style='background-color:  #fffbe6; padding: 15px; border-radius: 5px; margin-bottom: 20px; color: black; border-left: 5px solid red;'>
#     <h1 style='text-align: center; margin: 0; color: red;'>Chọn trọng số ảnh hưởng tới kết quả</h1>
# </div>

# %%
### Tình huống: trong nhiều bài toán việc k là số chẵn mà ta không yêu cầu
### tính trọng số cho từng lables của K hàng xóm gần nhất thì sẽ dẫn tới việc 
### Mô hình chọn ngẫu nhiên 1 trong nhiều lables có tỉ lệ bằng nhau --> Dẫn đến hiệu suất mô hình thấp
### Sau đây là ví dụ về điều trên


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler


## Bước 1: Đọc dữ liệu
penguins = np.genfromtxt("penguins.csv", delimiter = ',', skip_header = 1, dtype = str)
X_data = penguins[:, 2:6]
X_data = X_data.astype(float)
y_data = penguins[:, 0]

## Bước 2: Xử lý dữ liệu
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data,
                                                    test_size = 0.2,
                                                    random_state = 42)
# Bước 3: Chuẩn hóa dữ liệu
scaler = StandardScaler()
X_train_scaler = scaler.fit_transform(X_train)
X_test_scaler = scaler.transform(X_test)

# Bước 4: Build 2 model để so sánh
n_neighbors = list(range(1, 11))

scores_uniform = []
scores_distance = []

for k in n_neighbors:
    # KNN với trọng số đều    
    knn = KNeighborsClassifier(n_neighbors = k, p = 2, weights = 'uniform')
    pred1 = knn.fit(X_train_scaler, y_train)
    pred = pred1.predict(X_test_scaler)
    accuracy = accuracy_score(y_test, pred)
    scores_uniform .append(accuracy)

    # KNN với trọng số khoảng cách
    knn = KNeighborsClassifier(n_neighbors = k, p = 2, weights = 'distance')
    pred2 = knn.fit(X_train_scaler, y_train)
    pred_ = pred2.predict(X_test_scaler)
    accuracy = accuracy_score(y_test, pred_)
    scores_distance.append(accuracy)


# Bước 5: Vẽ biểu đồ so sánh
plt.figure(figsize=(10, 5))
plt.plot(n_neighbors, scores_uniform, label='weights=uniform')
plt.plot(n_neighbors, scores_distance, label='weights=distance')
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Accuracy')
plt.title('Comparison of KNN with uniform vs distance weights')
plt.legend()
plt.grid(True)
plt.show()
